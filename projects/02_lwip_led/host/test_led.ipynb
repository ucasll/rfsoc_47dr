# %%
from led_ctrl import LedController
# import led_ctrl

# %%
import led_ctrl

# %%
LedController.connect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 LedController.connect()
#
# NameError: name 'LedController' is not defined
