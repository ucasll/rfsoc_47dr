# %% [markdown]
# ### Simple led control by lwip

# %%
import socket
import time

# %%
from led_ctrl import LedController
# import led_ctrl

# %%
t = LedController()
t.connect()
# Out:
# Successfully connected to 192.168.1.10:6001
# True

# %%
t.send_val(9)
# Out:
# Sent:  9 (Binary: 1001)
